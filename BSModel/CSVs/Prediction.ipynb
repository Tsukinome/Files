# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import requests

pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Helper Functions

# %%
def plot_histogram_per_predclass(df, df_name):
    missing_percentage_per_class = {}
    total_rows_per_class = df.groupby('PredClass').size()
    
    for pred_class, group in df.groupby('PredClass'):
        missing_rows = group['Pred'].isnull().sum()
        missing_percentage = (missing_rows / total_rows_per_class[pred_class]) * 100
        missing_percentage_per_class[pred_class] = missing_percentage

    print(f"\n{df_name} - Percentage of missing 'Pred' values per 'PredClass':")
    for pred_class, missing_percentage in missing_percentage_per_class.items():
        print(f"{pred_class}: {missing_percentage:.2f}%")

    print(f"\n{df_name} - Number of rows per 'PredClass' where 'Pred' value is present:")
    for pred_class, group in df.groupby('PredClass'):
        rows_with_pred = group['Pred'].notnull().sum()
        print(f"{pred_class}: {rows_with_pred}")

        sorted_pred = group['Pred'].dropna().sort_values()   
        print(f"Top 5 highest 'Pred' values for {pred_class}: {sorted_pred[-5:].values}")
        print(f"Bottom 5 lowest 'Pred' values for {pred_class}: {sorted_pred[:5].values}")

    df_dropna = df.dropna(subset=['Pred'])
    plt.figure(figsize=(12, 6))
    for pred_class, group in df_dropna.groupby('PredClass'):
        plt.hist(group['Pred'], bins=20, alpha=0.5, label=str(pred_class))

    plt.xlabel('Pred Value')
    plt.ylabel('Frequency')
    plt.title(f'Histogram of Pred Values per PredClass for {df_name}')
    plt.legend(title='Pred Class', loc='upper right')
    plt.show()

# %% [markdown]
# ## Data Imports

# %%
directory = '/Users/kristinagrigaityte/PycharmProjects/pulls/Files/BSModel/Predictions'
csv_files = [file for file in os.listdir(directory) if file.endswith('.csv')]

for file in csv_files:
    df_name = os.path.splitext(file)[0] 
    globals()[df_name] = pd.read_csv(os.path.join(directory, file))

# %%
categories = ['Selection', 'Balancing Selection', 'Negative Freq-Dep. Selection', 'Overdominance']
prefixes = ['recent', 'old', 'medium']
indexes = ['1', '2', '3', '3']
chromosomes = ['ch1', 'ch2', 'ch3', 'ch4', 'ch5', 'ch6', 'ch7', 'ch8', 'ch9', 'ch10',
               'ch11', 'ch12', 'ch13', 'ch14', 'ch15', 'ch16', 'ch17', 'ch18', 'ch19', 'ch20', 'ch21', 'ch22']

data_list = []

for chrom in chromosomes:
    count_dict = {'chromosome': chrom}
    
    for prefix in prefixes:
        for i, category in zip(indexes, categories):
            category_name_parts = category.split()
            formatted_category_name = category_name_parts[0].lower() + ''.join(word.capitalize() for word in category_name_parts[1:])
            df_name = f'prediction_{prefix}_{i}_{chrom}'
            df = globals()[df_name]
            
            selected_rows = df[df['PredClass'] == category]
            
            count = selected_rows.shape[0]
            count_dict[f'{prefix}_{formatted_category_name}'] = count
            
            if category != 'Overdominance':
                if count > 0:
                    avg_score = selected_rows['Pred'].mean()
                else:
                    avg_score = 0.0
                count_dict[f'{prefix}_{formatted_category_name}_avg'] = f"{avg_score:.3f}"
    
    data_list.append(count_dict)

counts_df = pd.DataFrame(data_list)
pd.set_option('display.max_columns', None)
counts_df
# Out:
#    chromosome  recent_selection recent_selection_avg  \
# 0         ch1               150                0.998
# 1         ch2                 1                0.985
# 2         ch3               763                0.998
# 3         ch4               454                0.999
# 4         ch5               133                0.999
# 5         ch6              1393                0.998
# 6         ch7               353                0.999
# 7         ch8               145                0.994
# 8         ch9               390                0.999
# 9        ch10               429                0.999
# 10       ch11               375                0.999
# 11       ch12               555                0.999
# 12       ch13              1635                0.998
# 13       ch14                 7                0.956
# 14       ch15              1059                0.999
# 15       ch16               913                1.000
# 16       ch17               531                0.998
# 17       ch18               714                0.999
# 18       ch19               951                0.998
# 19       ch20               458                0.999
# 20       ch21               738                0.999
# 21       ch22              1224                0.999
#
#     recent_balancingSelection recent_balancingSelection_avg  \
# 0                          23                         0.606
# 1                           0                         0.000
# 2                         106                         0.619
# 3                          58                         0.594
# 4                          10                         0.579
# 5                         252                         0.601
# 6                          28                         0.599
# 7                          20                         0.567
# 8                          54                         0.629
# 9                          74                         0.615
# 10                         52                         0.586
# 11                         48                         0.599
# 12                        397                         0.619
# 13                          0                         0.000
# 14                        136                         0.609
# 15                        116                         0.593
# 16                         62                         0.589
# 17                        111                         0.588
# 18                        140                         0.577
# 19                         58                         0.596
# 20                        109                         0.597
# 21                        177                         0.610
#
#     recent_negativeFreq-dep.Selection recent_negativeFreq-dep.Selection_avg  \
# 0                                 147                                 0.565
# 1                                   1                                 0.526
# 2                                 738                                 0.552
# 3                                 453                                 0.573
# 4                                 133                                 0.573
# 5                                1375                                 0.562
# 6                                 350                                 0.580
# 7                                 144                                 0.546
# 8                                 385                                 0.579
# 9                                 425                                 0.584
# 10                                373                                 0.578
# 11                                550                                 0.588
# 12                               1604                                 0.556
# 13                                  7                                 0.525
# 14                               1048                                 0.578
# 15                                913                                 0.606
# 16                                529                                 0.581
# 17                                695                                 0.575
# 18                                933                                 0.560
# 19                                452                                 0.584
# 20                                729                                 0.573
# 21                               1206                                 0.581
#
#     recent_overdominance  old_selection old_selection_avg  \
# 0                   8583            150             0.997
# 1                   9060              1             0.986
# 2                   6633            763             0.998
# 3                   5730            454             0.999
# 4                   6339            133             0.999
# 5                   5693           1393             0.999
# 6                   5583            353             0.999
# 7                   5590            145             0.992
# 8                   4579            390             0.999
# 9                   5455            429             0.999
# 10                  5323            375             0.999
# 11                  4849            555             0.999
# 12                  2525           1635             0.998
# 13                  3500              7             0.944
# 14                  2389           1059             0.999
# 15                  2625            913             1.000
# 16                  2573            531             0.999
# 17                  2572            714             0.999
# 18                  1315            951             0.998
# 19                  2376            458             0.999
# 20                   789            738             0.999
# 21                   357           1224             0.999
#
#     old_balancingSelection old_balancingSelection_avg  \
# 0                        0                      0.000
# 1                        0                      0.000
# 2                       10                      0.602
# 3                        0                      0.000
# 4                        0                      0.000
# 5                        1                      0.520
# 6                        0                      0.000
# 7                        0                      0.000
# 8                        1                      0.509
# 9                        0                      0.000
# 10                       0                      0.000
# 11                       0                      0.000
# 12                      11                      0.552
# 13                       0                      0.000
# 14                       0                      0.000
# 15                       1                      0.516
# 16                       0                      0.000
# 17                       0                      0.000
# 18                       0                      0.000
# 19                       1                      0.511
# 20                       1                      0.507
# 21                       3                      0.536
#
#     old_negativeFreq-dep.Selection old_negativeFreq-dep.Selection_avg  \
# 0                              150                              0.655
# 1                                1                              0.549
# 2                              763                              0.628
# 3                              454                              0.676
# 4                              133                              0.672
# 5                             1393                              0.652
# 6                              353                              0.687
# 7                              145                              0.614
# 8                              390                              0.684
# 9                              429                              0.700
# 10                             375                              0.686
# 11                             555                              0.699
# 12                            1635                              0.641
# 13                               7                              0.548
# 14                            1059                              0.680
# 15                             913                              0.741
# 16                             531                              0.684
# 17                             714                              0.674
# 18                             951                              0.645
# 19                             458                              0.695
# 20                             738                              0.672
# 21                            1224                              0.688
#
#     old_overdominance  medium_selection medium_selection_avg  \
# 0                8580               150                1.000
# 1                9060                 1                0.998
# 2                6608               763                1.000
# 3                5729               454                1.000
# 4                6339               133                1.000
# 5                5675              1393                1.000
# 6                5580               353                1.000
# 7                5589               145                0.999
# 8                4574               390                1.000
# 9                5451               429                1.000
# 10               5321               375                1.000
# 11               4844               555                1.000
# 12               2494              1635                1.000
# 13               3500                 7                0.990
# 14               2378              1059                1.000
# 15               2625               913                1.000
# 16               2571               531                1.000
# 17               2553               714                1.000
# 18               1297               951                1.000
# 19               2370               458                1.000
# 20                780               738                1.000
# 21                339              1224                1.000
#
#     medium_balancingSelection medium_balancingSelection_avg  \
# 0                           0                         0.000
# 1                           0                         0.000
# 2                          17                         0.600
# 3                           0                         0.000
# 4                           0                         0.000
# 5                           1                         0.509
# 6                           0                         0.000
# 7                           0                         0.000
# 8                           0                         0.000
# 9                           0                         0.000
# 10                          0                         0.000
# 11                          1                         0.506
# 12                         24                         0.672
# 13                          0                         0.000
# 14                          0                         0.000
# 15                          0                         0.000
# 16                          0                         0.000
# 17                          0                         0.000
# 18                          5                         0.506
# 19                          0                         0.000
# 20                          1                         0.511
# 21                          6                         0.531
#
#     medium_negativeFreq-dep.Selection medium_negativeFreq-dep.Selection_avg  \
# 0                                 150                                 0.709
# 1                                   1                                 0.575
# 2                                 763                                 0.678
# 3                                 454                                 0.736
# 4                                 133                                 0.732
# 5                                1393                                 0.704
# 6                                 353                                 0.752
# 7                                 145                                 0.662
# 8                                 390                                 0.744
# 9                                 429                                 0.759
# 10                                375                                 0.745
# 11                                555                                 0.761
# 12                               1635                                 0.689
# 13                                  7                                 0.584
# 14                               1059                                 0.737
# 15                                913                                 0.802
# 16                                531                                 0.745
# 17                                714                                 0.730
# 18                                951                                 0.700
# 19                                458                                 0.756
# 20                                738                                 0.729
# 21                               1224                                 0.747
#
#     medium_overdominance
# 0                   8580
# 1                   9060
# 2                   6608
# 3                   5729
# 4                   6339
# 5                   5675
# 6                   5580
# 7                   5589
# 8                   4574
# 9                   5451
# 10                  5321
# 11                  4844
# 12                  2494
# 13                  3500
# 14                  2378
# 15                  2625
# 16                  2571
# 17                  2553
# 18                  1297
# 19                  2370
# 20                   780
# 21                   339

# %%
def plot_line_with_values(dataframe, prefix, legend_labels, colors, filename):
    relevant_columns = [col for col in dataframe.columns if col.startswith(prefix) and "_avg" in col]
    plot_data = dataframe[['chromosome'] + relevant_columns]
    
    plot_data.set_index('chromosome', inplace=True)
    plot_data = plot_data.apply(pd.to_numeric, errors='coerce')
    plot_data.dropna(subset=relevant_columns, how='all', inplace=True)
    
    ax = plot_data.plot(kind='line', figsize=(14, 7), color=colors, marker='o')
    plt.title(f'Line Plot for {prefix.capitalize()} Selection')
    plt.xlabel('Chromosome')
    plt.ylabel('Prediction Score')
    
    new_labels = [legend_labels.get(col, col) for col in relevant_columns]
    plt.legend(new_labels, title='Selection Type', bbox_to_anchor=(1.05, 1), loc='upper left')
    
    ax.set_xticks(range(len(plot_data.index)))
    ax.set_xticklabels(plot_data.index, rotation=45, ha='right')
    
    for line in ax.get_lines():
        for x, y in zip(line.get_xdata(), line.get_ydata()):
            if y == 0:
                ax.annotate(f'{y:.2f}', xy=(x, y), xytext=(5, 5), textcoords='offset points')

    plt.tight_layout()
    
    plt.tight_layout()
    plt.savefig(filename)
    plt.close()

legend_labels_avg = {
    'recent_selection_avg': 'Selection Prediction Average',
    'recent_balancingSelection_avg': 'Balancing Selection Prediction Average',
    'recent_negativeFreq-dep.Selection_avg': 'Negative Freq-dep. Selection Prediction Average',
    
    'old_selection_avg': 'Selection Prediction Average',
    'old_balancingSelection_avg': 'Balancing Selection Prediction Average',
    'old_negativeFreq-dep.Selection_avg': 'Negative Freq-dep. Selection Prediction Average',
    
    'medium_selection_avg': 'Selection Prediction Average',
    'medium_balancingSelection_avg': 'Balancing Selection Prediction Average',
    'medium_negativeFreq-dep.Selection_avg': 'Negative Freq-dep. Selection Prediction Average'
}

secure_blue = '#3357A4'
peaceful_mint = '#A0E0D8'
innovation_purple = '#879BEF'

colors_dict = {
    'old': [secure_blue, peaceful_mint, innovation_purple],
    'recent': [secure_blue, peaceful_mint, innovation_purple],
    'medium': [secure_blue, peaceful_mint, innovation_purple]
}

for prefix in ['old', 'recent', 'medium']:
    filename = f'{prefix}_selection_plot.png'
    plot_line_with_values(counts_df, prefix, legend_labels_avg, colors_dict[prefix], filename)
    plt.show()

# %%
def plot_stacked_bars(dataframe, prefix, legend_labels, colors, filename):
    relevant_columns = [col for col in dataframe.columns if col.startswith(prefix) and "avg" not in col]
    plot_data = dataframe[['chromosome'] + relevant_columns]

    plot_data.set_index('chromosome', inplace=True)

    ax = plot_data.plot(kind='bar', stacked=True, figsize=(14, 7), color=colors)
    plt.title(f'Stacked Bar Plot for {prefix.capitalize()} Selection')
    plt.xlabel('Chromosome')
    plt.ylabel('SNP Count')
    
    new_labels = [legend_labels.get(col, col) for col in relevant_columns]
    
    plt.legend(new_labels, title='Selection Type', bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
    plt.tight_layout()
    
    plt.savefig(filename)
    plt.close()

legend_labels = {
    'recent_selection': 'Selection',
    'recent_balancingSelection': 'Balancing Selection',
    'recent_negativeFreq-dep.Selection': 'Negative Freq-dep. Selection',
    'recent_overdominance': 'Overdominance',
    
    'old_selection': 'Selection',
    'old_balancingSelection': 'Balancing Selection',
    'old_negativeFreq-dep.Selection': 'Negative Freq-dep. Selection',
    'old_overdominance': 'Overdominance',
    
    'medium_selection': 'Selection',
    'medium_balancingSelection': 'Balancing Selection',
    'medium_negativeFreq-dep.Selection': 'Negative Freq-dep. Selection',
    'medium_overdominance': 'Overdominance',
}

secure_blue = '#879BEF'
peaceful_mint = '#FFBD00'
innovation_purple = '#72bcd4'
navy = '#3357A4'

colors_dict = {
    'old': [secure_blue, peaceful_mint, innovation_purple, navy],
    'recent': [secure_blue, peaceful_mint, innovation_purple, navy],
    'medium': [secure_blue, peaceful_mint, innovation_purple, navy]
}

for prefix in ['old', 'recent', 'medium']:
    filename = f"{prefix}_stacked_bar_plot.png"
    plot_stacked_bars(counts_df, prefix, legend_labels, colors_dict[prefix], filename)

# %%
available_dfs = [var_name for var_name, var in globals().items() if isinstance(var, pd.DataFrame)]

print("Available Dataframes:")
# for df_name in available_dfs:
#     print(df_name)
# Out:
# Available Dataframes:

# %% [markdown]
# ## Archaic Matches

# %%
archaic = pd.read_csv('/Users/kristinagrigaityte/PycharmProjects/pulls/Files/BSModel/Predictions/archaic.csv')
archaic.tail()
# Out:
#       chr  seg      from        to  AltaiNean  AltaiDeni
# 1594   22  103  49054049  49103380     0.5859     0.5636
# 1595   22  104  49103660  49153192     0.9831     0.9636
# 1596   22  105  49307031  49353474     0.1228     0.2586
# 1597   22  106  49404049  49450895     0.5225     0.5405
# 1598   22  107  49460591  49502569     0.7818     0.5862

# %%
def add_chr_column(df, chr_number):
    df = df.copy()
    df.loc[:, 'chr'] = chr_number
    return df

def get_df_name(prefix, chr_number):
    return f'{prefix}_ch{chr_number}'

prefixes = ['prediction_recent_1', 'prediction_recent_2', 'prediction_recent_3']
pred_classes = ["Selection", "Balancing Selection", "Overdominance", "Negative Freq-Dep. Selection"]
all_dfs = []

for chr_number in range(1, 23):   
    for prefix in prefixes:
        df_name = get_df_name(prefix, chr_number)
        try:
            df = globals()[df_name]
            for pred_class in pred_classes:
                filtered_df = df[df['PredClass'] == pred_class]
                if not filtered_df.empty:
                    filtered_df = add_chr_column(filtered_df, chr_number)
                    all_dfs.append(filtered_df)
        except KeyError:
            continue

all_data = pd.concat(all_dfs, ignore_index=True)
all_data.tail()
# Out:
#               SNP  Positions      Pred                     PredClass  chr
# 123025   rs131718   49404789  0.586998  Negative Freq-Dep. Selection   22
# 123026   rs131715   49413787  0.585034  Negative Freq-Dep. Selection   22
# 123027  rs9616915   49464446  0.550545  Negative Freq-Dep. Selection   22
# 123028   rs739365   49487182  0.597457  Negative Freq-Dep. Selection   22
# 123029  rs6009951   49498216  0.574389  Negative Freq-Dep. Selection   22

# %%
selection_snps = all_data[all_data['PredClass'] == 'Selection']['SNP'].unique()
filtered_df = all_data[all_data['PredClass'].isin(['Balancing Selection', 'Overdominance', 'Negative Freq-Dep. Selection'])]
all_data = filtered_df[filtered_df['SNP'].isin(selection_snps)]
all_data.head()
# Out:
#             SNP  Positions      Pred            PredClass  chr
# 150  rs10927011  241645735  0.550709  Balancing Selection    1
# 151    rs692981  242232230  0.517401  Balancing Selection    1
# 152   rs1000543  242254223  0.581432  Balancing Selection    1
# 153  rs10927137  242355096  0.580353  Balancing Selection    1
# 154    rs913994  242381803  0.574044  Balancing Selection    1

# %% [markdown]
# ### Genes

# %%
# %%time

def find_snps_in_range(row, all_data):
    snps_in_range = all_data[
        (all_data['chr'] == row['chr']) & 
        (all_data['Positions'] >= row['from']) & 
        (all_data['Positions'] <= row['to'])
    ]
    grouped_snps = snps_in_range.groupby('PredClass').agg({'SNP': list}).reset_index()
    return grouped_snps

new_rows = []

for _, row in archaic.iterrows():
    snps_grouped = find_snps_in_range(row, all_data)
    for _, snp_group in snps_grouped.iterrows():
        new_rows.append([
            row['chr'], row['seg'], row['from'], row['to'], row['AltaiNean'], row['AltaiDeni'],
            snp_group['SNP'], snp_group['PredClass']
        ])

flattened_df = pd.DataFrame(new_rows, columns=['chr', 'seg', 'from', 'to', 'AltaiNean', 'AltaiDeni', 'SNPs', 'PredClass'])
# Out:
# CPU times: user 892 ms, sys: 3.86 ms, total: 896 ms
# Wall time: 903 ms

# %%
flattened_df.tail()
# Out:
#       chr    seg        from          to  AltaiNean  AltaiDeni  \
# 171  22.0  102.0  49003874.0  49053529.0     0.1111     0.4744
# 172  22.0  105.0  49307031.0  49353474.0     0.1228     0.2586
# 173  22.0  105.0  49307031.0  49353474.0     0.1228     0.2586
# 174  22.0  106.0  49404049.0  49450895.0     0.5225     0.5405
# 175  22.0  107.0  49460591.0  49502569.0     0.7818     0.5862
#
#                                  SNPs                     PredClass
# 171             [rs742186, rs2235356]  Negative Freq-Dep. Selection
# 172                        [rs140519]           Balancing Selection
# 173              [rs140519, rs131778]  Negative Freq-Dep. Selection
# 174              [rs131718, rs131715]  Negative Freq-Dep. Selection
# 175  [rs9616915, rs739365, rs6009951]  Negative Freq-Dep. Selection

# %%
filtered_df = flattened_df[(flattened_df['AltaiNean'] > 0.85)]
filtered_df.tail()
# Out:
#       chr   seg        from          to  AltaiNean  AltaiDeni  \
# 132  22.0  56.0  35654133.0  35703551.0     0.8596     0.8305
# 135  22.0  59.0  36103709.0  36133397.0     1.0000     0.8636
# 146  22.0  81.0  44107968.0  44149935.0     0.9167     1.0000
# 147  22.0  81.0  44107968.0  44149935.0     0.9167     1.0000
# 160  22.0  93.0  47432419.0  47445957.0     0.9107     0.9630
#
#                                               SNPs  \
# 132                        [rs11089816, rs5750348]
# 135                         [rs4820286, rs5750428]
# 146  [rs11704481, rs2064068, rs1044742, rs5764698]
# 147  [rs11704481, rs2064068, rs1044742, rs5764698]
# 160                         [rs5771906, rs6010568]
#
#                         PredClass
# 132  Negative Freq-Dep. Selection
# 135  Negative Freq-Dep. Selection
# 146           Balancing Selection
# 147  Negative Freq-Dep. Selection
# 160  Negative Freq-Dep. Selection

# %%
# %%time

def get_genes_and_consequence_for_snp(snp_id, chr_column):
    server = "https://grch37.rest.ensembl.org"
    ext = f"/variation/human/{snp_id}?content-type=application/json"
    r = requests.get(server + ext, headers={"Content-Type": "application/json"})
    
    if not r.ok:
        return [], None
    
    data = r.json()
    genes = []
    consequence = data.get("most_severe_consequence", "unknown")
    
    if 'mappings' in data:
        for mapping in data['mappings']:
            location = f"{chr_column}:{mapping['start']}-{mapping['end']}"
            ext = f"/overlap/region/human/{location}?feature=gene;content-type=application/json"
            r = requests.get(server + ext, headers={"Content-Type": "application/json"})
            
            if not r.ok:
                continue
            
            gene_data = r.json()
            
            for gene in gene_data:
                genes.append(gene['id'])   
    
    return list(set(genes)), consequence

def add_gene_info(row):
    all_genes = []
    consequences = []
    chr_column = str(int(row['chr']))  
    
    for snp in row['SNPs']:
        gene_ids, consequence = get_genes_and_consequence_for_snp(snp, chr_column)
        if gene_ids:
            all_genes.extend(gene_ids)
        consequences.append(consequence)
    
    return list(set(all_genes)), consequences

filtered_df = filtered_df.copy()
filtered_df[['Genes', 'Consequences']] = filtered_df.apply(
    lambda row: pd.Series(add_gene_info(row)), axis=1)

# %%
filtered_df.head()
# Out:
#     chr    seg         from           to  AltaiNean  AltaiDeni  \
# 9   3.0   98.0  189261797.0  189309846.0     0.9394     0.8154
# 10  3.0  100.0  191112052.0  191161035.0     1.0000     0.8298
# 12  3.0  103.0  191661171.0  191710630.0     0.9479     0.9500
# 13  3.0  104.0  191711064.0  191755302.0     0.9818     1.0000
# 15  4.0  141.0  186117497.0  186164767.0     0.9268     0.7750
#
#                                  SNPs                     PredClass  \
# 9              [rs2037184, rs6444269]  Negative Freq-Dep. Selection
# 10  [rs12696598, rs724438, rs4687112]  Negative Freq-Dep. Selection
# 12  [rs3943979, rs9857115, rs2042865]  Negative Freq-Dep. Selection
# 13             [rs2193880, rs3773989]  Negative Freq-Dep. Selection
# 15                        [rs4355430]  Negative Freq-Dep. Selection
#
#                 Genes  \
# 9                  []
# 10                 []
# 12                 []
# 13  [ENSG00000196083]
# 15                 []
#
#                                                                   Consequences  \
# 9                                     [intergenic_variant, intergenic_variant]
# 10  [intergenic_variant, regulatory_region_variant, regulatory_region_variant]
# 12         [intergenic_variant, intergenic_variant, regulatory_region_variant]
# 13                                            [intron_variant, intron_variant]
# 15                                                        [intergenic_variant]
#
#                                                                               Proteins
# 9                                                                                   []
# 10                                                                                  []
# 12                                                                                  []
# 13  [[IL1RAP, interleukin 1 receptor accessory protein [Source:HGNC Symbol;Acc:5995]]]
# 15                                                                                  []

# %% [markdown]
# ### Proteins

# %%
# %%time

def get_protein_info_for_gene(gene_id):
    server = "https://grch37.rest.ensembl.org"
    ext = f"/lookup/id/{gene_id}?content-type=application/json"
    r = requests.get(server + ext, headers={"Content-Type": "application/json"})
    
    if not r.ok:
        return None
    
    data = r.json()
    protein_name = data.get('display_name', 'Unknown')
    description = data.get('description', 'No description available')
    
    return [protein_name, description]

def add_protein_info(genes):
    protein_info = []
    for gene in genes:
        info = get_protein_info_for_gene(gene)
        if info:
            protein_info.append(info)
    return protein_info

filtered_df['Proteins'] = filtered_df['Genes'].apply(add_protein_info)
# Out:
# CPU times: user 1.21 s, sys: 56.6 ms, total: 1.26 s
# Wall time: 6.34 s

# %%
filtered_df.to_csv("genes.csv", index=False)
filtered_df
# Out:
#       chr    seg         from           to  AltaiNean  AltaiDeni  \
# 9     3.0   98.0  189261797.0  189309846.0     0.9394     0.8154
# 10    3.0  100.0  191112052.0  191161035.0     1.0000     0.8298
# 12    3.0  103.0  191661171.0  191710630.0     0.9479     0.9500
# 13    3.0  104.0  191711064.0  191755302.0     0.9818     1.0000
# 15    4.0  141.0  186117497.0  186164767.0     0.9268     0.7750
# 17    6.0  104.0  143867336.0  143897977.0     0.9661     0.1379
# 18    6.0  110.0  156898474.0  156946230.0     0.8947     0.9459
# 19    6.0  110.0  156898474.0  156946230.0     0.8947     0.9459
# 20    6.0  112.0  159198260.0  159247967.0     0.9672     0.2143
# 23    6.0  115.0  161248552.0  161291617.0     0.9286     0.9032
# 25    6.0  117.0  163048514.0  163097724.0     0.9091     0.4182
# 31    9.0   65.0  129660977.0  129709828.0     0.8684     0.7714
# 32    9.0   65.0  129660977.0  129709828.0     0.8684     0.7714
# 33   10.0   80.0  127671175.0  127711500.0     0.9787     1.0000
# 48   13.0   34.0  102071812.0  102116884.0     0.8611     0.8734
# 49   13.0   34.0  102071812.0  102116884.0     0.8611     0.8734
# 52   13.0   39.0  107421329.0  107469601.0     0.9365     0.6349
# 53   15.0   14.0   86002672.0   86049988.0     1.0000     0.9483
# 54   15.0   16.0   89501124.0   89544688.0     1.0000     1.0000
# 68   17.0   19.0   65702659.0   65749953.0     0.8519     0.6786
# 71   17.0   22.0   68256221.0   68299201.0     0.9333     0.9839
# 86   19.0   34.0   52928986.0   52976774.0     0.8989     0.8452
# 92   21.0   27.0   28411654.0   28456611.0     0.8571     0.8636
# 122  22.0   46.0   34153779.0   34203496.0     0.9706     0.7778
# 123  22.0   46.0   34153779.0   34203496.0     0.9706     0.7778
# 131  22.0   56.0   35654133.0   35703551.0     0.8596     0.8305
# 132  22.0   56.0   35654133.0   35703551.0     0.8596     0.8305
# 135  22.0   59.0   36103709.0   36133397.0     1.0000     0.8636
# 146  22.0   81.0   44107968.0   44149935.0     0.9167     1.0000
# 147  22.0   81.0   44107968.0   44149935.0     0.9167     1.0000
# 160  22.0   93.0   47432419.0   47445957.0     0.9107     0.9630
#
#                                                                                SNPs  \
# 9                                                            [rs2037184, rs6444269]
# 10                                                [rs12696598, rs724438, rs4687112]
# 12                                                [rs3943979, rs9857115, rs2042865]
# 13                                                           [rs2193880, rs3773989]
# 15                                                                      [rs4355430]
# 17                                                                      [rs2128977]
# 18                                                                       [rs288976]
# 19                                                                       [rs288976]
# 20                                               [rs9457507, rs9457511, rs12200537]
# 23                                                                      [rs1962358]
# 25                                                                      [rs9356058]
# 31                                                                      [rs3780663]
# 32                                                                      [rs3780663]
# 33                                                                     [rs12251249]
# 48                                                                      [rs3736972]
# 49                                                                      [rs3736972]
# 52   [rs9520690, rs9520691, rs9520696, rs9514782, rs9514792, rs12871532, rs1022909]
# 53                                                                      [rs6496435]
# 54                                                         [rs12905479, rs17594552]
# 68                                                   [rs236586, rs236523, rs236531]
# 71                                                [rs1110614, rs4793484, rs9906450]
# 86                                                                      [rs2334295]
# 92                                     [rs2223743, rs6516819, rs9976944, rs2831534]
# 122                                                                     [rs5755730]
# 123                                                                     [rs5755730]
# 131                                                         [rs11089816, rs5750348]
# 132                                                         [rs11089816, rs5750348]
# 135                                                          [rs4820286, rs5750428]
# 146                                   [rs11704481, rs2064068, rs1044742, rs5764698]
# 147                                   [rs11704481, rs2064068, rs1044742, rs5764698]
# 160                                                          [rs5771906, rs6010568]
#
#                         PredClass                               Genes  \
# 9    Negative Freq-Dep. Selection                                  []
# 10   Negative Freq-Dep. Selection                                  []
# 12   Negative Freq-Dep. Selection                                  []
# 13   Negative Freq-Dep. Selection                   [ENSG00000196083]
# 15   Negative Freq-Dep. Selection                                  []
# 17   Negative Freq-Dep. Selection                                  []
# 18            Balancing Selection                                  []
# 19   Negative Freq-Dep. Selection                                  []
# 20   Negative Freq-Dep. Selection                   [ENSG00000203711]
# 23   Negative Freq-Dep. Selection                                  []
# 25   Negative Freq-Dep. Selection                   [ENSG00000112530]
# 31            Balancing Selection  [ENSG00000257524, ENSG00000106992]
# 32   Negative Freq-Dep. Selection  [ENSG00000257524, ENSG00000106992]
# 33   Negative Freq-Dep. Selection                   [ENSG00000148848]
# 48            Balancing Selection                   [ENSG00000134900]
# 49   Negative Freq-Dep. Selection                   [ENSG00000134900]
# 52   Negative Freq-Dep. Selection                                  []
# 53   Negative Freq-Dep. Selection                   [ENSG00000259560]
# 54   Negative Freq-Dep. Selection                   [ENSG00000185518]
# 68   Negative Freq-Dep. Selection                                  []
# 71   Negative Freq-Dep. Selection                   [ENSG00000133195]
# 86   Negative Freq-Dep. Selection                   [ENSG00000269656]
# 92   Negative Freq-Dep. Selection  [ENSG00000236532, ENSG00000232079]
# 122           Balancing Selection                                  []
# 123  Negative Freq-Dep. Selection                                  []
# 131           Balancing Selection                                  []
# 132  Negative Freq-Dep. Selection                                  []
# 135  Negative Freq-Dep. Selection  [ENSG00000243902, ENSG00000166897]
# 146           Balancing Selection  [ENSG00000100376, ENSG00000077935]
# 147  Negative Freq-Dep. Selection  [ENSG00000100376, ENSG00000077935]
# 160  Negative Freq-Dep. Selection                   [ENSG00000219438]
#
#                                                                                                                                             Consequences  \
# 9                                                                                                               [intergenic_variant, intergenic_variant]
# 10                                                                            [intergenic_variant, regulatory_region_variant, regulatory_region_variant]
# 12                                                                                   [intergenic_variant, intergenic_variant, regulatory_region_variant]
# 13                                                                                                                      [intron_variant, intron_variant]
# 15                                                                                                                                  [intergenic_variant]
# 17                                                                                                                           [regulatory_region_variant]
# 18                                                                                                                                  [intergenic_variant]
# 19                                                                                                                                  [intergenic_variant]
# 20                                                                                                      [intron_variant, intron_variant, intron_variant]
# 23                                                                                                                                  [intergenic_variant]
# 25                                                                                                                                      [intron_variant]
# 31                                                                                                                                      [intron_variant]
# 32                                                                                                                                      [intron_variant]
# 33                                                                                                                                      [intron_variant]
# 48                                                                                                                                  [synonymous_variant]
# 49                                                                                                                                  [synonymous_variant]
# 52   [regulatory_region_variant, intergenic_variant, intergenic_variant, intergenic_variant, intergenic_variant, intergenic_variant, intergenic_variant]
# 53                                                                                                                                      [intron_variant]
# 54                                                                                                                      [intron_variant, intron_variant]
# 68                                                                                          [intergenic_variant, intergenic_variant, intergenic_variant]
# 71                                                                                                      [intron_variant, intron_variant, intron_variant]
# 86                                                                                                                                      [intron_variant]
# 92                                                                                      [intron_variant, intron_variant, intron_variant, intron_variant]
# 122                                                                                                                                 [intergenic_variant]
# 123                                                                                                                                 [intergenic_variant]
# 131                                                                                                             [intergenic_variant, intergenic_variant]
# 132                                                                                                             [intergenic_variant, intergenic_variant]
# 135                                                                                                                     [intron_variant, intron_variant]
# 146                                                                         [intron_variant, 3_prime_UTR_variant, 3_prime_UTR_variant, missense_variant]
# 147                                                                         [intron_variant, 3_prime_UTR_variant, 3_prime_UTR_variant, missense_variant]
# 160                                                                                                                     [intron_variant, intron_variant]
#
#                                                                                                                                                                        Proteins
# 9                                                                                                                                                                            []
# 10                                                                                                                                                                           []
# 12                                                                                                                                                                           []
# 13                                                                                           [[IL1RAP, interleukin 1 receptor accessory protein [Source:HGNC Symbol;Acc:5995]]]
# 15                                                                                                                                                                           []
# 17                                                                                                                                                                           []
# 18                                                                                                                                                                           []
# 19                                                                                                                                                                           []
# 20                                                                                               [[C6orf99, chromosome 6 open reading frame 99 [Source:HGNC Symbol;Acc:21179]]]
# 23                                                                                                                                                                           []
# 25                                                                                                                 [[PACRG, PARK2 co-regulated [Source:HGNC Symbol;Acc:19152]]]
# 31                                                                          [[RP11-203J24.9, No description available], [AK1, adenylate kinase 1 [Source:HGNC Symbol;Acc:361]]]
# 32                                                                          [[RP11-203J24.9, No description available], [AK1, adenylate kinase 1 [Source:HGNC Symbol;Acc:361]]]
# 33                                                                                                     [[ADAM12, ADAM metallopeptidase domain 12 [Source:HGNC Symbol;Acc:190]]]
# 48                                                                                                            [[TPP2, tripeptidyl peptidase II [Source:HGNC Symbol;Acc:12016]]]
# 49                                                                                                            [[TPP2, tripeptidyl peptidase II [Source:HGNC Symbol;Acc:12016]]]
# 52                                                                                                                                                                           []
# 53                                                                                                                                   [[RP11-648K4.2, No description available]]
# 54                                                                                                    [[SV2B, synaptic vesicle glycoprotein 2B [Source:HGNC Symbol;Acc:16874]]]
# 68                                                                                                                                                                           []
# 71                                                                                             [[SLC39A11, solute carrier family 39, member 11 [Source:HGNC Symbol;Acc:14463]]]
# 86                                                                                                                                  [[CTD-2571L23.6, No description available]]
# 92                                                                                             [[AL035610.2, No description available], [AL035610.1, No description available]]
# 122                                                                                                                                                                          []
# 123                                                                                                                                                                          []
# 131                                                                                                                                                                          []
# 132                                                                                                                                                                          []
# 135            [[RP1-63G5.5, No description available], [ELFN2, extracellular leucine-rich repeat and fibronectin type III domain containing 2 [Source:HGNC Symbol;Acc:29396]]]
# 146  [[FAM118A, family with sequence similarity 118, member A [Source:HGNC Symbol;Acc:1313]], [SMC1B, structural maintenance of chromosomes 1B [Source:HGNC Symbol;Acc:11112]]]
# 147  [[FAM118A, family with sequence similarity 118, member A [Source:HGNC Symbol;Acc:1313]], [SMC1B, structural maintenance of chromosomes 1B [Source:HGNC Symbol;Acc:11112]]]
# 160                                                      [[FAM19A5, family with sequence similarity 19 (chemokine (C-C motif)-like), member A5 [Source:HGNC Symbol;Acc:21592]]]

# %%
def collect_protein_names(df):
    protein_data = []

    for index, row in df.iterrows():
        pred_class = row['PredClass']
        proteins = row['Proteins']
        
        for protein in proteins:
            protein_name = protein[0]
            protein_data.append((pred_class, protein_name))

    return protein_data

protein_data = collect_protein_names(filtered_df)
protein_df = pd.DataFrame(protein_data, columns=['PredClass', 'Protein'])
result_df = protein_df.groupby(['PredClass', 'Protein']).size()
pd.set_option('display.max_rows', None)
result_df
# Out:
# PredClass                     Protein
# Balancing Selection           AK1              1
#                               FAM118A          1
#                               RP11-203J24.9    1
#                               SMC1B            1
#                               TPP2             1
# Negative Freq-Dep. Selection  ADAM12           1
#                               AK1              1
#                               AL035610.1       1
#                               AL035610.2       1
#                               C6orf99          1
#                               CTD-2571L23.6    1
#                               ELFN2            1
#                               FAM118A          1
#                               FAM19A5          1
#                               IL1RAP           1
#                               PACRG            1
#                               RP1-63G5.5       1
#                               RP11-203J24.9    1
#                               RP11-648K4.2     1
#                               SLC39A11         1
#                               SMC1B            1
#                               SV2B             1
#                               TPP2             1
# dtype: int64

# %%
proteins = pd.read_csv('/Users/kristinagrigaityte/PycharmProjects/pulls/Files/BSModel/Predictions/proteins.csv')
proteins
# Out:
#           Protein  \
# 0             AK1
# 1         FAM118A
# 2           SMC1B
# 3        SLC39A11
# 4    RP11-648K4.2
# 5   RP11-203J24.9
# 6      RP1-63G5.5
# 7           PACRG
# 8          IL1RAP
# 9         FAM19A5
# 10          ELFN2
# 11  CTD-2571L23.6
# 12        C6orf99
# 13     AL035610.2
# 14     AL035610.1
# 15         ADAM12
# 16           TPP2
# 17           SV2B
#
#                                                                              Function
# 0      Involved in the regulation of adenylate kinase activity and energy metabolism.
# 1                        Potential role in cellular processes and disease mechanisms.
# 2   Part of the cohesin complex, important for chromosome segregation during meiosis.
# 3                          Zinc transporter involved in maintaining zinc homeostasis.
# 4                                       Non-coding RNA, function not well understood.
# 5                                         Non-coding RNA, potential regulatory roles.
# 6                                       Non-coding RNA, function not well understood.
# 7             Associated with Parkinson’s disease, involved in microtubule stability.
# 8        Interleukin-1 receptor accessory protein, involved in inflammatory response.
# 9                            Potentially involved in neural development and function.
# 10                                               Potential role in synapse formation.
# 11                                      Non-coding RNA, function not well understood.
# 12                  Chromosome 6 open reading frame 99, function not well understood.
# 13                                      Non-coding RNA, function not well understood.
# 14                                      Non-coding RNA, function not well understood.
# 15               Metalloprotease involved in cell adhesion, signaling, and migration.
# 16                         Tripeptidyl peptidase II, involved in protein degradation.
# 17                Synaptic vesicle glycoprotein involved in neurotransmitter release.
