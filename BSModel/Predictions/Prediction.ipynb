# %%
import pandas as pd
import os
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import requests

pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Helper Functions

# %%
def plot_histogram_per_predclass(df, df_name):
    missing_percentage_per_class = {}
    total_rows_per_class = df.groupby('PredClass').size()
    
    for pred_class, group in df.groupby('PredClass'):
        missing_rows = group['Pred'].isnull().sum()
        missing_percentage = (missing_rows / total_rows_per_class[pred_class]) * 100
        missing_percentage_per_class[pred_class] = missing_percentage

    print(f"\n{df_name} - Percentage of missing 'Pred' values per 'PredClass':")
    for pred_class, missing_percentage in missing_percentage_per_class.items():
        print(f"{pred_class}: {missing_percentage:.2f}%")

    print(f"\n{df_name} - Number of rows per 'PredClass' where 'Pred' value is present:")
    for pred_class, group in df.groupby('PredClass'):
        rows_with_pred = group['Pred'].notnull().sum()
        print(f"{pred_class}: {rows_with_pred}")

        sorted_pred = group['Pred'].dropna().sort_values()   
        print(f"Top 5 highest 'Pred' values for {pred_class}: {sorted_pred[-5:].values}")
        print(f"Bottom 5 lowest 'Pred' values for {pred_class}: {sorted_pred[:5].values}")

    df_dropna = df.dropna(subset=['Pred'])
    plt.figure(figsize=(12, 6))
    for pred_class, group in df_dropna.groupby('PredClass'):
        plt.hist(group['Pred'], bins=20, alpha=0.5, label=str(pred_class))

    plt.xlabel('Pred Value')
    plt.ylabel('Frequency')
    plt.title(f'Histogram of Pred Values per PredClass for {df_name}')
    plt.legend(title='Pred Class', loc='upper right')
    plt.show()

# %% [markdown]
# ## Data Imports

# %%
directory = '/Users/kristinagrigaityte/PycharmProjects/pulls/Files/BSModel/Predictions'
csv_files = [file for file in os.listdir(directory) if file.endswith('.csv')]

for file in csv_files:
    df_name = os.path.splitext(file)[0] 
    globals()[df_name] = pd.read_csv(os.path.join(directory, file))

# %%
categories = ['Selection', 'Balancing Selection', 'Negative Freq-Dep. Selection', 'Overdominance']
prefixes = ['recent', 'old', 'medium']
indexes = ['1', '2', '3', '3']
chromosomes = ['ch1', 'ch2', 'ch3', 'ch4', 'ch5', 'ch6', 'ch7', 'ch8', 'ch9', 'ch10',
               'ch11', 'ch12', 'ch13', 'ch14', 'ch15', 'ch16', 'ch17', 'ch18', 'ch19', 'ch20', 'ch21', 'ch22']

data_list = []

for chrom in chromosomes:
    count_dict = {'chromosome': chrom}
    
    for prefix in prefixes:
        for i, category in zip(indexes, categories):
            category_name_parts = category.split()
            formatted_category_name = category_name_parts[0].lower() + ''.join(word.capitalize() for word in category_name_parts[1:])
            df_name = f'prediction_{prefix}_{i}_{chrom}'
            df = globals()[df_name]
            
            selected_rows = df[df['PredClass'] == category]
            
            count = selected_rows.shape[0]
            count_dict[f'{prefix}_{formatted_category_name}'] = count
            
            if category != 'Overdominance':
                if count > 0:
                    avg_score = selected_rows['Pred'].mean()
                else:
                    avg_score = 0.0
                count_dict[f'{prefix}_{formatted_category_name}_avg'] = f"{avg_score:.3f}"
    
    data_list.append(count_dict)

counts_df = pd.DataFrame(data_list)
counts_df
# Out:
#    chromosome  recent_selection recent_selection_avg  \
# 0         ch1               150                0.998
# 1         ch2                 1                0.985
# 2         ch3               763                0.998
# 3         ch4               454                0.999
# 4         ch5               133                0.999
# 5         ch6              1393                0.998
# 6         ch7               353                0.999
# 7         ch8               145                0.994
# 8         ch9               390                0.999
# 9        ch10               429                0.999
# 10       ch11               375                0.999
# 11       ch12               555                0.999
# 12       ch13              1635                0.998
# 13       ch14                 7                0.956
# 14       ch15              1059                0.999
# 15       ch16               913                1.000
# 16       ch17               531                0.998
# 17       ch18               714                0.999
# 18       ch19               951                0.998
# 19       ch20               458                0.999
# 20       ch21               738                0.999
# 21       ch22              1224                0.999
#
#     recent_balancingSelection recent_balancingSelection_avg  \
# 0                          23                         0.606
# 1                           0                         0.000
# 2                         106                         0.619
# 3                          58                         0.594
# 4                          10                         0.579
# 5                         252                         0.601
# 6                          28                         0.599
# 7                          20                         0.567
# 8                          54                         0.629
# 9                          74                         0.615
# 10                         52                         0.586
# 11                         48                         0.599
# 12                        397                         0.619
# 13                          0                         0.000
# 14                        136                         0.609
# 15                        116                         0.593
# 16                         62                         0.589
# 17                        111                         0.588
# 18                        140                         0.577
# 19                         58                         0.596
# 20                        109                         0.597
# 21                        177                         0.610
#
#     recent_negativeFreq-dep.Selection recent_negativeFreq-dep.Selection_avg  \
# 0                                 147                                 0.565
# 1                                   1                                 0.526
# 2                                 738                                 0.552
# 3                                 453                                 0.573
# 4                                 133                                 0.573
# 5                                1375                                 0.562
# 6                                 350                                 0.580
# 7                                 144                                 0.546
# 8                                 385                                 0.579
# 9                                 425                                 0.584
# 10                                373                                 0.578
# 11                                550                                 0.588
# 12                               1604                                 0.556
# 13                                  7                                 0.525
# 14                               1048                                 0.578
# 15                                913                                 0.606
# 16                                529                                 0.581
# 17                                695                                 0.575
# 18                                933                                 0.560
# 19                                452                                 0.584
# 20                                729                                 0.573
# 21                               1206                                 0.581
#
#     recent_overdominance  old_selection old_selection_avg  ...  \
# 0                   8583            150             0.997  ...
# 1                   9060              1             0.986  ...
# 2                   6633            763             0.998  ...
# 3                   5730            454             0.999  ...
# 4                   6339            133             0.999  ...
# 5                   5693           1393             0.999  ...
# 6                   5583            353             0.999  ...
# 7                   5590            145             0.992  ...
# 8                   4579            390             0.999  ...
# 9                   5455            429             0.999  ...
# 10                  5323            375             0.999  ...
# 11                  4849            555             0.999  ...
# 12                  2525           1635             0.998  ...
# 13                  3500              7             0.944  ...
# 14                  2389           1059             0.999  ...
# 15                  2625            913             1.000  ...
# 16                  2573            531             0.999  ...
# 17                  2572            714             0.999  ...
# 18                  1315            951             0.998  ...
# 19                  2376            458             0.999  ...
# 20                   789            738             0.999  ...
# 21                   357           1224             0.999  ...
#
#     old_negativeFreq-dep.Selection old_negativeFreq-dep.Selection_avg  \
# 0                              150                              0.655
# 1                                1                              0.549
# 2                              763                              0.628
# 3                              454                              0.676
# 4                              133                              0.672
# 5                             1393                              0.652
# 6                              353                              0.687
# 7                              145                              0.614
# 8                              390                              0.684
# 9                              429                              0.700
# 10                             375                              0.686
# 11                             555                              0.699
# 12                            1635                              0.641
# 13                               7                              0.548
# 14                            1059                              0.680
# 15                             913                              0.741
# 16                             531                              0.684
# 17                             714                              0.674
# 18                             951                              0.645
# 19                             458                              0.695
# 20                             738                              0.672
# 21                            1224                              0.688
#
#     old_overdominance medium_selection  medium_selection_avg  \
# 0                8580              150                 1.000
# 1                9060                1                 0.998
# 2                6608              763                 1.000
# 3                5729              454                 1.000
# 4                6339              133                 1.000
# 5                5675             1393                 1.000
# 6                5580              353                 1.000
# 7                5589              145                 0.999
# 8                4574              390                 1.000
# 9                5451              429                 1.000
# 10               5321              375                 1.000
# 11               4844              555                 1.000
# 12               2494             1635                 1.000
# 13               3500                7                 0.990
# 14               2378             1059                 1.000
# 15               2625              913                 1.000
# 16               2571              531                 1.000
# 17               2553              714                 1.000
# 18               1297              951                 1.000
# 19               2370              458                 1.000
# 20                780              738                 1.000
# 21                339             1224                 1.000
#
#     medium_balancingSelection medium_balancingSelection_avg  \
# 0                           0                         0.000
# 1                           0                         0.000
# 2                          17                         0.600
# 3                           0                         0.000
# 4                           0                         0.000
# 5                           1                         0.509
# 6                           0                         0.000
# 7                           0                         0.000
# 8                           0                         0.000
# 9                           0                         0.000
# 10                          0                         0.000
# 11                          1                         0.506
# 12                         24                         0.672
# 13                          0                         0.000
# 14                          0                         0.000
# 15                          0                         0.000
# 16                          0                         0.000
# 17                          0                         0.000
# 18                          5                         0.506
# 19                          0                         0.000
# 20                          1                         0.511
# 21                          6                         0.531
#
#     medium_negativeFreq-dep.Selection medium_negativeFreq-dep.Selection_avg  \
# 0                                 150                                 0.709
# 1                                   1                                 0.575
# 2                                 763                                 0.678
# 3                                 454                                 0.736
# 4                                 133                                 0.732
# 5                                1393                                 0.704
# 6                                 353                                 0.752
# 7                                 145                                 0.662
# 8                                 390                                 0.744
# 9                                 429                                 0.759
# 10                                375                                 0.745
# 11                                555                                 0.761
# 12                               1635                                 0.689
# 13                                  7                                 0.584
# 14                               1059                                 0.737
# 15                                913                                 0.802
# 16                                531                                 0.745
# 17                                714                                 0.730
# 18                                951                                 0.700
# 19                                458                                 0.756
# 20                                738                                 0.729
# 21                               1224                                 0.747
#
#     medium_overdominance
# 0                   8580
# 1                   9060
# 2                   6608
# 3                   5729
# 4                   6339
# 5                   5675
# 6                   5580
# 7                   5589
# 8                   4574
# 9                   5451
# 10                  5321
# 11                  4844
# 12                  2494
# 13                  3500
# 14                  2378
# 15                  2625
# 16                  2571
# 17                  2553
# 18                  1297
# 19                  2370
# 20                   780
# 21                   339
#
# [22 rows x 22 columns]

# %%
def plot_line_with_values(dataframe, prefix, legend_labels, colors, filename):
    relevant_columns = [col for col in dataframe.columns if col.startswith(prefix) and "_avg" in col]
    plot_data = dataframe[['chromosome'] + relevant_columns]
    
    plot_data.set_index('chromosome', inplace=True)
    plot_data = plot_data.apply(pd.to_numeric, errors='coerce')
    plot_data.dropna(subset=relevant_columns, how='all', inplace=True)
    
    ax = plot_data.plot(kind='line', figsize=(14, 7), color=colors, marker='o')
    plt.title(f'Line Plot for {prefix.capitalize()} Selection')
    plt.xlabel('Chromosome')
    plt.ylabel('Prediction Score')
    
    new_labels = [legend_labels.get(col, col) for col in relevant_columns]
    plt.legend(new_labels, title='Selection Type', bbox_to_anchor=(1.05, 1), loc='upper left')
    
    ax.set_xticks(range(len(plot_data.index)))
    ax.set_xticklabels(plot_data.index, rotation=45, ha='right')
    
    for line in ax.get_lines():
        for x, y in zip(line.get_xdata(), line.get_ydata()):
            if y == 0:
                ax.annotate(f'{y:.2f}', xy=(x, y), xytext=(5, 5), textcoords='offset points')

    plt.tight_layout()
    
    plt.tight_layout()
    plt.savefig(filename)
    plt.close()

legend_labels_avg = {
    'recent_selection_avg': 'Selection Prediction Average',
    'recent_balancingSelection_avg': 'Balancing Selection Prediction Average',
    'recent_negativeFreq-dep.Selection_avg': 'Negative Freq-dep. Selection Prediction Average',
    
    'old_selection_avg': 'Selection Prediction Average',
    'old_balancingSelection_avg': 'Balancing Selection Prediction Average',
    'old_negativeFreq-dep.Selection_avg': 'Negative Freq-dep. Selection Prediction Average',
    
    'medium_selection_avg': 'Selection Prediction Average',
    'medium_balancingSelection_avg': 'Balancing Selection Prediction Average',
    'medium_negativeFreq-dep.Selection_avg': 'Negative Freq-dep. Selection Prediction Average'
}

secure_blue = '#3357A4'
peaceful_mint = '#A0E0D8'
innovation_purple = '#879BEF'

colors_dict = {
    'old': [secure_blue, peaceful_mint, innovation_purple],
    'recent': [secure_blue, peaceful_mint, innovation_purple],
    'medium': [secure_blue, peaceful_mint, innovation_purple]
}

for prefix in ['old', 'recent', 'medium']:
    filename = f'{prefix}_selection_plot.png'
    plot_line_with_values(counts_df, prefix, legend_labels_avg, colors_dict[prefix], filename)
    plt.show()

# %%
def plot_stacked_bars(dataframe, prefix, legend_labels, colors, filename):
    relevant_columns = [col for col in dataframe.columns if col.startswith(prefix) and "avg" not in col]
    plot_data = dataframe[['chromosome'] + relevant_columns]

    plot_data.set_index('chromosome', inplace=True)

    ax = plot_data.plot(kind='bar', stacked=True, figsize=(14, 7), color=colors)
    plt.title(f'Stacked Bar Plot for {prefix.capitalize()} Selection')
    plt.xlabel('Chromosome')
    plt.ylabel('SNP Count')
    
    new_labels = [legend_labels.get(col, col) for col in relevant_columns]
    
    plt.legend(new_labels, title='Selection Type', bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
    plt.tight_layout()
    
    plt.savefig(filename)
    plt.close()

legend_labels = {
    'recent_selection': 'Selection',
    'recent_balancingSelection': 'Balancing Selection',
    'recent_negativeFreq-dep.Selection': 'Negative Freq-dep. Selection',
    'recent_overdominance': 'Overdominance',
    
    'old_selection': 'Selection',
    'old_balancingSelection': 'Balancing Selection',
    'old_negativeFreq-dep.Selection': 'Negative Freq-dep. Selection',
    'old_overdominance': 'Overdominance',
    
    'medium_selection': 'Selection',
    'medium_balancingSelection': 'Balancing Selection',
    'medium_negativeFreq-dep.Selection': 'Negative Freq-dep. Selection',
    'medium_overdominance': 'Overdominance',
}

secure_blue = '#879BEF'
peaceful_mint = '#FFBD00'
innovation_purple = '#72bcd4'
navy = '#3357A4'

colors_dict = {
    'old': [secure_blue, peaceful_mint, innovation_purple, navy],
    'recent': [secure_blue, peaceful_mint, innovation_purple, navy],
    'medium': [secure_blue, peaceful_mint, innovation_purple, navy]
}

for prefix in ['old', 'recent', 'medium']:
    filename = f"{prefix}_stacked_bar_plot.png"
    plot_stacked_bars(counts_df, prefix, legend_labels, colors_dict[prefix], filename)

# %%
available_dfs = [var_name for var_name, var in globals().items() if isinstance(var, pd.DataFrame)]

print("Available Dataframes:")
for df_name in available_dfs:
    print(df_name)
# Out:
# Available Dataframes:
# __
# ___
# prediction_recent_1_ch15
# prediction_old_1_ch15
# prediction_medium_3_ch21
# prediction_medium_2_ch21
# prediction_old_1_ch5
# prediction_medium_1_ch3
# prediction_medium_1_ch2
# prediction_old_1_ch4
# prediction_medium_2_ch20
# prediction_medium_3_ch20
# prediction_old_1_ch14
# prediction_recent_1_ch14
# prediction_recent_1_ch16
# prediction_old_1_ch16
# prediction_medium_2_ch22
# prediction_medium_3_ch22
# prediction_old_1_ch6
# prediction_medium_1_ch1
# prediction_old_1_ch7
# prediction_old_1_ch17
# prediction_recent_1_ch17
# prediction_old_1_ch13
# prediction_recent_1_ch13
# prediction_old_1_ch3
# prediction_recent_1_ch9
# prediction_medium_1_ch5
# prediction_medium_1_ch4
# prediction_recent_1_ch8
# prediction_old_1_ch2
# prediction_recent_1_ch12
# prediction_old_1_ch12
# prediction_old_1_ch10
# prediction_recent_1_ch10
# prediction_medium_3_ch18
# prediction_medium_2_ch18
# prediction_medium_1_ch6
# prediction_medium_1_ch7
# prediction_old_1_ch1
# prediction_medium_2_ch19
# prediction_medium_3_ch19
# prediction_recent_1_ch11
# prediction_old_1_ch11
# prediction_recent_2_ch19
# prediction_recent_3_ch9
# prediction_recent_3_ch19
# prediction_old_2_ch19
# prediction_old_3_ch19
# prediction_old_3_ch3
# prediction_medium_1_ch11
# prediction_medium_3_ch5
# prediction_old_2_ch6
# prediction_old_2_ch7
# prediction_medium_3_ch4
# prediction_medium_1_ch10
# prediction_old_3_ch18
# prediction_old_3_ch2
# prediction_old_2_ch18
# prediction_recent_3_ch8
# prediction_recent_3_ch18
# prediction_medium_2_ch1
# prediction_recent_2_ch18
# prediction_medium_2_ch3
# prediction_medium_1_ch12
# prediction_medium_3_ch6
# prediction_old_2_ch5
# archaic
# prediction_old_2_ch4
# prediction_medium_3_ch7
# prediction_medium_1_ch13
# prediction_old_3_ch1
# prediction_medium_2_ch2
# prediction_old_3_ch5
# prediction_medium_2_ch6
# prediction_medium_1_ch17
# prediction_medium_3_ch3
# prediction_medium_3_ch2
# prediction_old_2_ch1
# prediction_medium_1_ch16
# prediction_medium_2_ch7
# prediction_old_2_ch22
# prediction_old_3_ch22
# prediction_recent_2_ch22
# prediction_old_3_ch4
# prediction_recent_3_ch22
# prediction_recent_2_ch20
# prediction_recent_3_ch20
# prediction_old_3_ch6
# prediction_old_2_ch20
# prediction_medium_2_ch5
# prediction_old_3_ch20
# prediction_medium_1_ch14
# prediction_old_2_ch3
# prediction_recent_2_ch9
# prediction_medium_3_ch1
# prediction_recent_2_ch8
# prediction_old_2_ch2
# prediction_medium_1_ch15
# prediction_old_3_ch21
# prediction_medium_2_ch4
# prediction_old_2_ch21
# prediction_old_3_ch7
# prediction_recent_3_ch21
# prediction_recent_2_ch21
# prediction_old_3_ch10
# prediction_old_2_ch10
# prediction_recent_3_ch10
# prediction_recent_2_ch10
# prediction_medium_2_ch9
# prediction_medium_1_ch18
# prediction_recent_2_ch5
# prediction_recent_2_ch4
# prediction_medium_1_ch19
# prediction_recent_2_ch11
# prediction_medium_2_ch8
# prediction_recent_3_ch11
# prediction_recent_3_ch1
# prediction_old_2_ch11
# prediction_old_3_ch11
# prediction_old_2_ch13
# prediction_old_3_ch13
# prediction_old_3_ch9
# prediction_recent_2_ch13
# prediction_recent_3_ch3
# prediction_recent_3_ch13
# prediction_recent_2_ch6
# prediction_recent_2_ch7
# prediction_recent_3_ch2
# prediction_recent_3_ch12
# prediction_recent_2_ch12
# prediction_old_3_ch12
# prediction_old_3_ch8
# prediction_old_2_ch12
# prediction_recent_2_ch16
# prediction_recent_3_ch16
# prediction_recent_3_ch6
# prediction_old_2_ch16
# prediction_old_3_ch16
# prediction_medium_1_ch22
# prediction_recent_2_ch3
# prediction_old_2_ch9
# prediction_old_2_ch8
# prediction_recent_2_ch2
# prediction_old_3_ch17
# prediction_old_2_ch17
# prediction_recent_3_ch17
# prediction_recent_3_ch7
# prediction_recent_2_ch17
# prediction_recent_3_ch5
# prediction_recent_3_ch15
# prediction_recent_2_ch15
# prediction_old_3_ch15
# prediction_old_2_ch15
# prediction_medium_1_ch21
# prediction_medium_3_ch9
# proteins
# prediction_recent_2_ch1
# prediction_medium_3_ch8
# prediction_medium_1_ch20
# prediction_old_2_ch14
# prediction_old_3_ch14
# prediction_recent_2_ch14
# prediction_recent_3_ch4
# prediction_recent_3_ch14
# prediction_recent_1_ch20
# prediction_old_1_ch20
# prediction_medium_2_ch14
# prediction_medium_3_ch14
# prediction_recent_1_ch6
# prediction_recent_1_ch7
# prediction_medium_3_ch15
# prediction_medium_2_ch15
# prediction_old_1_ch21
# prediction_recent_1_ch21
# prediction_medium_3_ch17
# prediction_medium_2_ch17
# prediction_recent_1_ch5
# prediction_medium_1_ch9
# prediction_medium_1_ch8
# prediction_recent_1_ch4
# prediction_medium_2_ch16
# prediction_medium_3_ch16
# prediction_old_1_ch22
# prediction_recent_1_ch22
# prediction_medium_3_ch12
# prediction_medium_2_ch12
# prediction_recent_1_ch1
# prediction_medium_2_ch13
# prediction_medium_3_ch13
# prediction_recent_1_ch19
# prediction_old_1_ch19
# prediction_medium_2_ch11
# prediction_medium_3_ch11
# prediction_recent_1_ch3
# prediction_old_1_ch9
# prediction_old_1_ch8
# prediction_recent_1_ch2
# prediction_medium_3_ch10
# prediction_medium_2_ch10
# prediction_old_1_ch18
# prediction_recent_1_ch18
# df
# selected_rows
# counts_df
# _4
# _8
# ch3_bal
# ch6_bal
# ch13_bal
# ch15_bal
# ch16_bal
# ch18_bal
# ch19_bal
# ch21_bal
# ch22_bal
# ch3_over
# ch6_over
# ch13_over
# ch15_over
# ch16_over
# ch18_over
# ch19_over
# ch21_over
# ch22_over
# ch3_neg
# ch6_neg
# ch13_neg
# ch15_neg
# ch16_neg
# ch18_neg
# ch19_neg
# ch21_neg
# ch22_neg
# all_data
# _10
# snps_grouped
# flattened_df
# _12
# filtered_df
# _13
# _15
# _16
# _17
# _18
# _20
# _21
# _23
# _24
# protein_df
# result_df
# _25
# _26
# gene_counts
# _27
# _31
# _35
# _37
# _39
# _40
# _44
# _48
# _53
# _54
# _55
# _57
# _59
# _60
# _61
# _62
# _66
# _67
# _68
# _69
# _70
# _85

# %% [markdown]
# ## Archaic Matches

# %%
archaic = pd.read_csv('/Users/kristinagrigaityte/PycharmProjects/pulls/Files/BSModel/Predictions/archaic.csv')
archaic.tail()
# Out:
#       chr  seg      from        to  AltaiNean  AltaiDeni
# 1594   22  103  49054049  49103380     0.5859     0.5636
# 1595   22  104  49103660  49153192     0.9831     0.9636
# 1596   22  105  49307031  49353474     0.1228     0.2586
# 1597   22  106  49404049  49450895     0.5225     0.5405
# 1598   22  107  49460591  49502569     0.7818     0.5862

# %%
def add_chr_column(df, chr_number):
    df = df.copy()
    df.loc[:, 'chr'] = chr_number
    return df

def get_df_name(prefix, chr_number):
    return f'{prefix}_ch{chr_number}'

prefixes = ['prediction_recent_2', 'prediction_recent_3']
pred_classes = ["Balancing Selection", "Overdominance", "Negative Freq-Dep. Selection"]
all_dfs = []

for chr_number in range(1, 23):  # Using 1 to 2 for this example
    for prefix in prefixes:
        df_name = get_df_name(prefix, chr_number)
        try:
            df = globals()[df_name]
            for pred_class in pred_classes:
                filtered_df = df[df['PredClass'] == pred_class]
                if not filtered_df.empty:
                    filtered_df = add_chr_column(filtered_df, chr_number)
                    all_dfs.append(filtered_df)
        except KeyError:
            continue

all_data = pd.concat(all_dfs, ignore_index=True)
all_data.tail()
# Out:
#               SNP  Positions      Pred                     PredClass  chr
# 109654   rs131718   49404789  0.586998  Negative Freq-Dep. Selection   22
# 109655   rs131715   49413787  0.585034  Negative Freq-Dep. Selection   22
# 109656  rs9616915   49464446  0.550545  Negative Freq-Dep. Selection   22
# 109657   rs739365   49487182  0.597457  Negative Freq-Dep. Selection   22
# 109658  rs6009951   49498216  0.574389  Negative Freq-Dep. Selection   22

# %% [markdown]
# ### Genes

# %%
# %%time

def find_snps_in_range(row, all_data):
    snps_in_range = all_data[
        (all_data['chr'] == row['chr']) & 
        (all_data['Positions'] >= row['from']) & 
        (all_data['Positions'] <= row['to'])
    ]
    grouped_snps = snps_in_range.groupby('PredClass').agg({'SNP': list}).reset_index()
    return grouped_snps

new_rows = []

for _, row in archaic.iterrows():
    snps_grouped = find_snps_in_range(row, all_data)
    for _, snp_group in snps_grouped.iterrows():
        new_rows.append([
            row['chr'], row['seg'], row['from'], row['to'], row['AltaiNean'], row['AltaiDeni'],
            snp_group['SNP'], snp_group['PredClass']
        ])

flattened_df = pd.DataFrame(new_rows, columns=['chr', 'seg', 'from', 'to', 'AltaiNean', 'AltaiDeni', 'SNPs', 'PredClass'])
# Out:
# CPU times: user 1.18 s, sys: 30.7 ms, total: 1.22 s
# Wall time: 1.24 s

# %%
flattened_df.head()
# Out:
#    chr  seg        from          to  AltaiNean  AltaiDeni  \
# 0  1.0  0.0   1613367.0   1662895.0     0.6667     0.3529
# 1  1.0  1.0   4568842.0   4612366.0     0.8226     0.8438
# 2  1.0  2.0   6563721.0   6612894.0     0.2703     0.1081
# 3  1.0  3.0   7415787.0   7462976.0     0.3509     0.4407
# 4  1.0  8.0  21763132.0  21812739.0     0.3125     0.2632
#
#                                                                                                                         SNPs  \
# 0                                                                                                                [rs3817856]
# 1                                                                                [rs763219, rs2411887, rs1905304, rs1107467]
# 2                                                                                                               [rs12127219]
# 3  [rs9988557, rs1750836, rs2693953, rs6702132, rs1149331, rs1149335, rs1011124, rs1011127, rs1149338, rs1193182, rs1193185]
# 4                                                                                                               [rs12124283]
#
#        PredClass
# 0  Overdominance
# 1  Overdominance
# 2  Overdominance
# 3  Overdominance
# 4  Overdominance

# %%
row_count = len(flattened_df)
print(row_count)
# Out:
# 1111

# %%
filtered_df = flattened_df[(flattened_df['AltaiNean'] > 0.9) & (flattened_df['AltaiDeni'] > 0.9)]
filtered_df.head()
# Out:
#     chr   seg         from           to  AltaiNean  AltaiDeni  \
# 25  1.0  44.0  120063627.0  120112597.0     0.9286     0.9250
# 47  1.0  83.0  219913313.0  219963090.0     1.0000     1.0000
# 49  1.0  85.0  227313297.0  227361299.0     1.0000     1.0000
# 50  1.0  86.0  227363765.0  227411863.0     1.0000     1.0000
# 58  2.0   3.0    1336661.0    1378969.0     0.9821     0.9836
#
#                                                                                                             SNPs  \
# 25                                                                      [rs523395, rs517237, rs532208, rs536662]
# 47  [rs7523649, rs953111, rs1815577, rs11118827, rs6687398, rs908857, rs2280339, rs908858, rs982292, rs17010629]
# 49                                                                                                   [rs3923210]
# 50                                            [rs6693489, rs365684, rs12026629, rs869676, rs8179432, rs10916446]
# 58                                                                             [rs9749785, rs4927602, rs4076290]
#
#         PredClass
# 25  Overdominance
# 47  Overdominance
# 49  Overdominance
# 50  Overdominance
# 58  Overdominance

# %%
row_count = len(filtered_df)
print(row_count)
# Out:
# 92

# %%
# %%time

def get_genes_for_snp(snp_id, chr_column):
    server = "https://grch37.rest.ensembl.org"
    ext = f"/variation/human/{snp_id}?content-type=application/json"
    r = requests.get(server + ext, headers={"Content-Type": "application/json"})
    
    if not r.ok:
        return []
    
    data = r.json()
    genes = []
    
    if 'mappings' in data:
        for mapping in data['mappings']:
            location = f"{chr_column}:{mapping['start']}-{mapping['end']}"
            ext = f"/overlap/region/human/{location}?feature=gene;content-type=application/json"
            r = requests.get(server + ext, headers={"Content-Type": "application/json"})
            
            if not r.ok:
                continue
            
            gene_data = r.json()
            
            for gene in gene_data:
                genes.append(gene['id'])   
    
    return list(set(genes))

def add_gene_info(row):
    all_genes = []
    chr_column = str(int(row['chr']))  
    
    for snp in row['SNPs']:
        gene_ids = get_genes_for_snp(snp, chr_column)
        if gene_ids:
            all_genes.extend(gene_ids)
    
    return list(set(all_genes))

filtered_df = filtered_df.copy()
filtered_df['Genes'] = filtered_df.apply(add_gene_info, axis=1)
# Out:
# CPU times: user 53.6 s, sys: 2.53 s, total: 56.1 s
# Wall time: 6min 17s

# %%
filtered_df.tail()
# Out:
#        chr    seg        from          to  AltaiNean  AltaiDeni  \
# 1073  22.0   81.0  44107968.0  44149935.0     0.9167     1.0000
# 1074  22.0   81.0  44107968.0  44149935.0     0.9167     1.0000
# 1075  22.0   81.0  44107968.0  44149935.0     0.9167     1.0000
# 1090  22.0   93.0  47432419.0  47445957.0     0.9107     0.9630
# 1104  22.0  104.0  49103660.0  49153192.0     0.9831     0.9636
#
#                                                SNPs  \
# 1073  [rs11704481, rs2064068, rs1044742, rs5764698]
# 1074  [rs11704481, rs2064068, rs1044742, rs5764698]
# 1075                          [rs9614462, rs719925]
# 1090                         [rs5771906, rs6010568]
# 1104                                    [rs4074135]
#
#                          PredClass                               Genes
# 1073           Balancing Selection  [ENSG00000100376, ENSG00000077935]
# 1074  Negative Freq-Dep. Selection  [ENSG00000100376, ENSG00000077935]
# 1075                 Overdominance                   [ENSG00000077935]
# 1090  Negative Freq-Dep. Selection                   [ENSG00000219438]
# 1104                 Overdominance                   [ENSG00000205593]

# %%
row_count = len(filtered_df)
print(row_count)
# Out:
# 92

# %% [markdown]
# ### Proteins

# %%
# %%time

def get_protein_info_for_gene(gene_id):
    server = "https://grch37.rest.ensembl.org"
    ext = f"/lookup/id/{gene_id}?content-type=application/json"
    r = requests.get(server + ext, headers={"Content-Type": "application/json"})
    
    if not r.ok:
        return None
    
    data = r.json()
    protein_name = data.get('display_name', 'Unknown')
    description = data.get('description', 'No description available')
    
    return [protein_name, description]

def add_protein_info(genes):
    protein_info = []
    for gene in genes:
        info = get_protein_info_for_gene(gene)
        if info:
            protein_info.append(info)
    return protein_info

filtered_df['Proteins'] = filtered_df['Genes'].apply(add_protein_info)
filtered_df = filtered_df[~((filtered_df['Genes'] == '[]') & (filtered_df['Proteins'] == '[]'))]
# Out:
# CPU times: user 3.85 s, sys: 199 ms, total: 4.05 s
# Wall time: 25.6 s

# %%
filtered_df
# Out:
#        chr    seg         from           to  AltaiNean  AltaiDeni  \
# 25     1.0   44.0  120063627.0  120112597.0     0.9286     0.9250
# 47     1.0   83.0  219913313.0  219963090.0     1.0000     1.0000
# 49     1.0   85.0  227313297.0  227361299.0     1.0000     1.0000
# 50     1.0   86.0  227363765.0  227411863.0     1.0000     1.0000
# 58     2.0    3.0    1336661.0    1378969.0     0.9821     0.9836
# 62     2.0    7.0   10931001.0   10979979.0     0.9186     0.9877
# 66     2.0   13.0   21381268.0   21416614.0     0.9712     0.9608
# 95     2.0   50.0   64530894.0   64579779.0     0.9200     0.9796
# 97     2.0   52.0   71032316.0   71079245.0     0.9677     0.9677
# 104    2.0   62.0   79234333.0   79280710.0     0.9149     0.9200
# 106    2.0   64.0   82181683.0   82229132.0     0.9643     0.9821
# 121    2.0   86.0  120986708.0  121029586.0     0.9706     0.9706
# 129    2.0   99.0  154081517.0  154130112.0     1.0000     0.9286
# 131    2.0  103.0  166882828.0  166920909.0     1.0000     1.0000
# 137    2.0  113.0  196032265.0  196079530.0     0.9275     0.9265
# 160    3.0   12.0   16764023.0   16809683.0     0.9333     0.9310
# 166    3.0   20.0   27613983.0   27656577.0     0.9767     1.0000
# 178    3.0   38.0   82713305.0   82760557.0     0.9512     0.9500
# 184    3.0   53.0  119862702.0  119910524.0     0.9756     0.9756
# 224    3.0  103.0  191661171.0  191710630.0     0.9479     0.9500
# 481                                                                                                                                                                                                                             [rs1003620, rs11973256]
# 482                                                                                                                                                                                                                                         [rs4729731]
# 491                                                                                                                                                                                                                                          [rs336673]
# 513                                                                                                                                                                                                      [rs1528628, rs1203096, rs13250216, rs10888181]
# 520                                                                                                                                                                                                       [rs11135963, rs2046187, rs6557962, rs1481646]
# 540                                                                                                                                                                                                                              [rs830771, rs10092405]
# 547                                                                                                                                                                                                                              [rs4133395, rs4472483]
# 550                                                                                                                                                                                                                                        [rs13282733]
# 594                                                                                                                                                                                                                               [rs805050, rs2796033]
# 622                                                                                                                                                                                                                                         [rs2802477]
# 627                                                                                                                                                                                                                  [rs7097813, rs10733977, rs9416634]
# 635                                                                                                                                                                                                                             [rs1925562, rs10997462]
# 641                                                                                                                                                                                                                                        [rs10749572]
# 648                                                                                                                                                                                              [rs1334579, rs2118824, rs1318550, rs7096430, rs934901]
# 650                                                                                                                                                                                                                            [rs10882544, rs11188197]
# 657                                                                                                                                                                                                                                        [rs12251249]
# 660                                                                                                                                                                                                                                         [rs2272566]
# 686                                                                                                                                                                                                                                        [rs10769641]
# 688                                                                                                                                                                                                                                         [rs4409856]
# 703                                                                                                                                                                                                                   [rs7940252, rs2114413, rs1426651]
# 707                                                                                                                                                                                                                                [rs628310, rs675333]
# 725                                                                                                                                                                                                                                         [rs4936956]
# 799                                                                                                                                                                                                                                         [rs1341550]
# 822                                                                                                                                                                                                                                         [rs1684685]
# 837                                                                                                                                                                                                                             [rs2210184, rs10139559]
# 850                                                                                                                                                                                                                                         [rs7175635]
# 855                                                                                                                                                                                                                                         [rs6496435]
# 856                                                                                                                                                                                                                            [rs12905479, rs17594552]
# 896                                                                                                                                                                                             [rs8070707, rs1634411, rs1737944, rs1634423, rs4924949]
# 907                                                                                                                                                                                                                   [rs1110614, rs4793484, rs9906450]
# 961                                                                                                                                                                                                           [rs6135360, rs175223, rs175259, rs175262]
# 963                                                                                                                                                                                                                              [rs6046722, rs1887553]
# 977                                                                                                                                                                                             [rs7279893, rs2823121, rs2823139, rs2823141, rs2823145]
# 1033                                                                                                                                                                                                                                        [rs9621951]
# 1043                                                                                                                                                                                                                                         [rs909675]
# 1073                                                                                                                                                                                                      [rs11704481, rs2064068, rs1044742, rs5764698]
# 1074                                                                                                                                                                                                      [rs11704481, rs2064068, rs1044742, rs5764698]
# 1075                                                                                                                                                                                                                              [rs9614462, rs719925]
# 1090                                                                                                                                                                                                                             [rs5771906, rs6010568]
# 1104                                                                                                                                                                                                                                        [rs4074135]
#
#                          PredClass  \
# 25                   Overdominance
# 47                   Overdominance
# 49                   Overdominance
# 50                   Overdominance
# 58                   Overdominance
# 62                   Overdominance
# 66                   Overdominance
# 95                   Overdominance
# 97                   Overdominance
# 104                  Overdominance
# 106                  Overdominance
# 121                  Overdominance
# 129                  Overdominance
# 131                  Overdominance
# 137                  Overdominance
# 160                  Overdominance
# 166                  Overdominance
# 178                  Overdominance
# 184                  Overdominance
# 224   Negative Freq-Dep. Selection
# 225                  Overdominance
# 226   Negative Freq-Dep. Selection
# 242                  Overdominance
# 261                  Overdominance
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [[FAM118A, family with sequence similarity 118, member A [Source:HGNC Symbol;Acc:1313]], [SMC1B, structural maintenance of chromosomes 1B [Source:HGNC Symbol;Acc:11112]]]
# 1075                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [[SMC1B, structural maintenance of chromosomes 1B [Source:HGNC Symbol;Acc:11112]]]
# 1090                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [[FAM19A5, family with sequence similarity 19 (chemokine (C-C motif)-like), member A5 [Source:HGNC Symbol;Acc:21592]]]
# 1104                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [[DENND6B, DENN/MADD domain containing 6B [Source:HGNC Symbol;Acc:32690]]]

# %%
row_count = len(filtered_df)
print(row_count)
# Out:
# 92

# %%
def collect_protein_names(df):
    protein_data = []

    for index, row in df.iterrows():
        pred_class = row['PredClass']
        proteins = row['Proteins']
        
        for protein in proteins:
            protein_name = protein[0]
            protein_data.append((pred_class, protein_name))

    return protein_data

protein_data = collect_protein_names(filtered_df)
protein_df = pd.DataFrame(protein_data, columns=['PredClass', 'Protein'])
result_df = protein_df.groupby(['PredClass', 'Protein']).size().reset_index(name='Count')
result_df = result_df.sort_values(by=['Count'], ascending=[False])
pd.set_option('display.max_rows', None)
result_df
# Out:
#                        PredClass             Protein  Count
# 42                 Overdominance            HLA-DRB5      2
# 80                 Overdominance                TAP2      2
# 0            Balancing Selection             FAM118A      1
# 56                 Overdominance             MACROD2      1
# 64                 Overdominance              PSMD13      1
# 63                 Overdominance               PSMB9      1
# 62                 Overdominance               PSMB8      1
# 61                 Overdominance             PRPSAP2      1
# 60                 Overdominance              POU5F1      1
# 59                 Overdominance               PHGDH      1
# 58                 Overdominance                MICE      1
# 57                 Overdominance               MANEA      1
# 54                 Overdominance           LINC01007      1
# 55                 Overdominance              LRRTM3      1
# 66                 Overdominance            PSORS1C2      1
# 53                 Overdominance                INIP      1
# 52                 Overdominance             IFITM4P      1
# 51                 Overdominance               HNF4G      1
# 50                 Overdominance              HMGCS2      1
# 49                 Overdominance               HLA-V      1
# 48                 Overdominance               HLA-P      1
# 47                 Overdominance               HLA-G      1
# 65                 Overdominance            PSORS1C1      1
# 67                 Overdominance            PSORS1C3      1
# 45                 Overdominance               HLA-F      1
# 78                 Overdominance               SNX30      1
# 87                 Overdominance  XXbac-BPG299F13.16      1
# 86                 Overdominance   XXbac-BPG254F23.7      1
# 85                 Overdominance  XXbac-BPG248L24.13      1
# 84                 Overdominance  XXbac-BPG170G13.31      1
# 83                 Overdominance                 TPO      1
# 82                 Overdominance               TCF19      1
# 81                 Overdominance             TAPSAR1      1
# 79                 Overdominance                TAP1      1
# 77                 Overdominance               SNTG2      1
# 68                 Overdominance       RP11-138I17.1      1
# 76                 Overdominance               SMC1B      1
# 75                 Overdominance             SLC5A10      1
# 74                 Overdominance               SCN9A      1
# 73                 Overdominance       RP5-1119A7.14      1
# 72                 Overdominance         RP3-455E7.1      1
# 71                 Overdominance        RP13-578N3.3      1
# 70                 Overdominance        RP11-762E8.1      1
# 69                 Overdominance       RP11-236B18.2      1
# 46                 Overdominance           HLA-F-AS1      1
# 44                 Overdominance            HLA-DRB9      1
# 1            Balancing Selection               SMC1B      1
# 11                 Overdominance          AC008074.4      1
# 19                 Overdominance              ANGPT1      1
# 18                 Overdominance                 AK9      1
# 17                 Overdominance          AC090286.4      1
# 16                 Overdominance          AC067959.1      1
# 15                 Overdominance          AC064834.1      1
# 14                 Overdominance          AC012501.2      1
# 13                 Overdominance          AC011754.1      1
# 12                 Overdominance          AC011288.2      1
# 10                 Overdominance         AC007040.11      1
# 21                 Overdominance               BTNL2      1
# 9   Negative Freq-Dep. Selection                SV2B      1
# 8   Negative Freq-Dep. Selection               SMC1B      1
# 7   Negative Freq-Dep. Selection            SLC39A11      1
# 6   Negative Freq-Dep. Selection        RP11-648K4.2      1
# 5   Negative Freq-Dep. Selection              IL1RAP      1
# 4   Negative Freq-Dep. Selection             FAM19A5      1
# 3   Negative Freq-Dep. Selection             FAM118A      1
# 2   Negative Freq-Dep. Selection              ADAM12      1
# 20                 Overdominance            ATP6V1B1      1
# 22                 Overdominance            C20orf26      1
# 43                 Overdominance            HLA-DRB6      1
# 33                 Overdominance               HCG23      1
# 41                 Overdominance             HLA-DRA      1
# 40                 Overdominance            HLA-DQB3      1
# 39                 Overdominance            HLA-DQB1      1
# 38                 Overdominance            HLA-DQA2      1
# 37                 Overdominance            HLA-DQA1      1
# 36                 Overdominance               HLA-C      1
# 35                 Overdominance             HCG4P11      1
# 34                 Overdominance               HCG27      1
# 32                 Overdominance             FAM111B      1
# 23                 Overdominance              CCHCR1      1
# 31                 Overdominance              DUSP10      1
# 30                 Overdominance                DLC1      1
# 29                 Overdominance             DENND6B      1
# 28                 Overdominance              CTNNA3      1
# 27                 Overdominance              CTNNA2      1
# 26                 Overdominance               CNTN5      1
# 25                 Overdominance                CDSN      1
# 24                 Overdominance              CCSER1      1
# 88                 Overdominance             ZNF204P      1

# %%
proteins = pd.read_csv('/Users/kristinagrigaityte/PycharmProjects/pulls/Files/BSModel/Predictions/proteins.csv')
proteins
# Out:
#                                    Function             Protein  \
# 0   Immune System and Inflammatory Response            HLA-DRB5
# 1   Immune System and Inflammatory Response                TAP2
# 2                 General Cellular Function             FAM118A
# 3                 General Cellular Function             MACROD2
# 4                 General Cellular Function              PSMD13
# 5   Immune System and Inflammatory Response               PSMB9
# 6   Immune System and Inflammatory Response               PSMB8
# 7                 General Cellular Function             PRPSAP2
# 8                           Gene Regulation              POU5F1
# 9               Metabolism and Biosynthesis               PHGDH
# 10                            Not Available                MICE
# 11                General Cellular Function               MANEA
# 12                          Gene Regulation           LINC01007
# 13          Neural Development and Function              LRRTM3
# 14  Immune System and Inflammatory Response            PSORS1C2
# 15                General Cellular Function                INIP
# 16  Immune System and Inflammatory Response             IFITM4P
# 17                          Gene Regulation               HNF4G
# 18              Metabolism and Biosynthesis              HMGCS2
# 19  Immune System and Inflammatory Response               HLA-V
# 20  Immune System and Inflammatory Response               HLA-P
# 21  Immune System and Inflammatory Response               HLA-G
# 22  Immune System and Inflammatory Response            PSORS1C1
# 23  Immune System and Inflammatory Response            PSORS1C3
# 24  Immune System and Inflammatory Response               HLA-F
# 25                General Cellular Function               SNX30
# 26                            Not Available  XXbac-BPG299F13.16
# 27                            Not Available   XXbac-BPG254F23.7
# 28                            Not Available  XXbac-BPG248L24.13
# 29                            Not Available  XXbac-BPG170G13.31
# 30              Metabolism and Biosynthesis                 TPO
# 31                          Gene Regulation               TCF19
# 32                General Cellular Function             TAPSAR1
# 33                General Cellular Function                TAP1
# 34          Neural Development and Function               SNTG2
# 35                            Not Available       RP11-138I17.1
# 36                General Cellular Function               SMC1B
# 37                                Transport             SLC5A10
# 38          Neural Development and Function               SCN9A
# 39                            Not Available       RP5-1119A7.14
# 40                            Not Available         RP3-455E7.1
# 41                            Not Available        RP13-578N3.3
# 42                            Not Available        RP11-762E8.1
# 43                            Not Available       RP11-236B18.2
# 44                          Gene Regulation           HLA-F-AS1
# 45  Immune System and Inflammatory Response            HLA-DRB9
# 46                General Cellular Function               SMC1B
# 47                            Not Available          AC008074.4
# 48              Metabolism and Biosynthesis              ANGPT1
# 49              Metabolism and Biosynthesis                 AK9
# 50                            Not Available          AC090286.4
# 51                            Not Available          AC067959.1
# 52                            Not Available          AC064834.1
# 53                            Not Available          AC012501.2
# 54                            Not Available          AC011754.1
# 55                            Not Available          AC011288.2
# 56                            Not Available         AC007040.11
# 57  Immune System and Inflammatory Response               BTNL2
# 58          Neural Development and Function                SV2B
# 59                General Cellular Function               SMC1B
# 60                                Transport            SLC39A11
# 61                            Not Available        RP11-648K4.2
# 62  Immune System and Inflammatory Response              IL1RAP
# 63          Neural Development and Function             FAM19A5
# 64                General Cellular Function             FAM118A
# 65                General Cellular Function              ADAM12
# 66                General Cellular Function            ATP6V1B1
# 67                            Not Available            C20orf26
# 68  Immune System and Inflammatory Response            HLA-DRB6
# 69                            Not Available               HCG23
# 70  Immune System and Inflammatory Response             HLA-DRA
# 71  Immune System and Inflammatory Response            HLA-DQB3
# 72  Immune System and Inflammatory Response            HLA-DQB1
# 73  Immune System and Inflammatory Response            HLA-DQA2
# 74  Immune System and Inflammatory Response            HLA-DQA1
# 75  Immune System and Inflammatory Response               HLA-C
# 76                            Not Available             HCG4P11
# 77                            Not Available               HCG27
# 78                        Genetic Disorders             FAM111B
# 79  Immune System and Inflammatory Response              CCHCR1
# 80                General Cellular Function              DUSP10
# 81                         Tumor Suppressor                DLC1
# 82                General Cellular Function             DENND6B
# 83                General Cellular Function              CTNNA3
# 84                General Cellular Function              CTNNA2
# 85          Neural Development and Function               CNTN5
# 86                General Cellular Function                CDSN
# 87                General Cellular Function              CCSER1
# 88                            Not Available             ZNF204P
#
#                                                                     Description
# 0                         Involved in antigen presentation and immune response.
# 1                   Plays a role in peptide transport for antigen presentation.
# 2                                   Associated with various cellular functions.
# 3                                      Involved in protein de-ADP-ribosylation.
# 4                 A subunit of the proteasome, involved in protein degradation.
# 5                 Part of the immunoproteasome, involved in antigen processing.
# 6                 Part of the immunoproteasome, involved in antigen processing.
# 7                                          Involved in nucleotide biosynthesis.
# 8               Essential for maintaining pluripotency in embryonic stem cells.
# 9                                              Involved in serine biosynthesis.
# 10                                           No specific description available.
# 11                                         Involved in glycosylation processes.
# 12                               Long non-coding RNA with regulatory functions.
# 13                        Involved in synaptic function and neural development.
# 14                                    Associated with psoriasis susceptibility.
# 15                                            Involved in DNA repair processes.
# 16                           Involved in immune response and antiviral defense.
# 17                             Regulates gene expression in liver and pancreas.
# 18                                                     Involved in ketogenesis.
# 19                                                 Involved in immune response.
# 20                                                 Involved in immune response.
# 21                           Plays a role in immune tolerance during pregnancy.
# 22                                    Associated with psoriasis susceptibility.
# 23                                    Associated with psoriasis susceptibility.
# 24            Involved in immune system regulation, particularly with NK cells.
# 25                                       Involved in intracellular trafficking.
# 26                                           No specific description available.
# 27                                           No specific description available.
# 28                                           No specific description available.
# 29                                           No specific description available.
# 30                                       Involved in thyroid hormone synthesis.
# 31                         Transcription factor involved in cell proliferation.
# 32                                               Involved in peptide transport.
# 33                  Plays a role in peptide transport for antigen presentation.
# 34                                               Involved in synaptic function.
# 35                                           No specific description available.
# 36                        Involved in chromosome cohesion during cell division.
# 37                                                Sodium/glucose cotransporter.
# 38                                  Sodium channel involved in pain perception.
# 39                                           No specific description available.
# 40                                           No specific description available.
# 41                                           No specific description available.
# 42                                           No specific description available.
# 43                                           No specific description available.
# 44                                   Long non-coding RNA associated with HLA-F.
# 45                                            Involved in antigen presentation.
# 46                        Involved in chromosome cohesion during cell division.
# 47                                           No specific description available.
# 48                        Involved in angiogenesis and blood vessel maturation.
# 49                                           Involved in nucleotide metabolism.
# 50                                           No specific description available.
# 51                                           No specific description available.
# 52                                           No specific description available.
# 53                                           No specific description available.
# 54                                           No specific description available.
# 55                                           No specific description available.
# 56                                           No specific description available.
# 57                                               Involved in immune regulation.
# 58                                       Involved in synaptic vesicle function.
# 59                        Involved in chromosome cohesion during cell division.
# 60                                                            Zinc transporter.
# 61                                           No specific description available.
# 62  Interleukin-1 receptor accessory protein involved in inflammatory response.
# 63                                             Involved in neuronal activities.
# 64                                  Associated with various cellular functions.
# 65          Metalloprotease involved in cell-cell and cell-matrix interactions.
# 66                   Part of the vacuolar ATPase, involved in proton transport.
# 67                                           No specific description available.
# 68                                            Involved in antigen presentation.
# 69                                           No specific description available.
# 70                                            Involved in antigen presentation.
# 71                                            Involved in antigen presentation.
# 72                                            Involved in antigen presentation.
# 73                                            Involved in antigen presentation.
# 74                                            Involved in antigen presentation.
# 75                                            Involved in antigen presentation.
# 76                                           No specific description available.
# 77                                           No specific description available.
# 78   Involved in cellular processes, mutations linked to Kenny-Caffey syndrome.
# 79                                    Associated with psoriasis susceptibility.
# 80                          Involved in immune response and cell proliferation.
# 81          Tumor suppressor gene involved in cell migration and proliferation.
# 82                                             Involved in vesicle trafficking.
# 83                                                   Involved in cell adhesion.
# 84                                                   Involved in cell adhesion.
# 85                                              Involved in neural development.
# 86                                         Involved in epidermal cell adhesion.
# 87                                              Involved in cellular processes.
# 88                                           No specific description available.

# %%
gene_counts = proteins.groupby('Function').size().reset_index(name='Protein Count')
gene_counts
# Out:
#                                   Function  Protein Count
# 0                          Gene Regulation              5
# 1                General Cellular Function             21
# 2                        Genetic Disorders              1
# 3  Immune System and Inflammatory Response             23
# 4              Metabolism and Biosynthesis              5
# 5          Neural Development and Function              6
# 6                            Not Available             25
# 7                                Transport              2
# 8                         Tumor Suppressor              1
